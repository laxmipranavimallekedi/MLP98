# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical

# %%
# 1. Load the data
asthma = pd.read_csv("/content/asthma_disease_data (1).csv")

# 2. Handle categorical data
categorical_cols = ['Gender', 'Ethnicity', 'EducationLevel', 'Smoking',
                    'PhysicalActivity', 'DietQuality', 'SleepQuality',
                    'PollutionExposure', 'PollenExposure', 'DustExposure',
                    'PetAllergy', 'FamilyHistoryAsthma', 'HistoryOfAllergies',
                    'Eczema', 'HayFever', 'GastroesophagealReflux',
                    'Wheezing', 'ShortnessOfBreath', 'ChestTightness',
                    'Coughing', 'NighttimeSymptoms', 'ExerciseInduced']

asthma = asthma.drop(columns=['PatientID', 'DoctorInCharge'])

# Label encode categorical features
for col in categorical_cols:
    le = LabelEncoder()
    asthma[col] = le.fit_transform(asthma[col].astype(str))

# Encode target variable
target_le = LabelEncoder()
asthma['Diagnosis'] = target_le.fit_transform(asthma['Diagnosis'])

# 3. Define features and labels
X = asthma.drop('Diagnosis', axis=1)
y = asthma['Diagnosis']

# 4. Normalize numerical features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 5. Train/test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# 6. Build neural network model
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))  # Use softmax if multiclass

# 7. Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# 8. Train model
history = model.fit(X_train, y_train, epochs=50, batch_size=16, validation_split=0.1)

# 9. Evaluate model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy:.2f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8891 - loss: 0.3595 - val_accuracy: 0.9427 - val_loss: 0.2350
# Epoch 2/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9459 - loss: 0.2377 - val_accuracy: 0.9427 - val_loss: 0.2301
# Epoch 3/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9504 - loss: 0.2060 - val_accuracy: 0.9427 - val_loss: 0.2275
# Epoch 4/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9387 - loss: 0.2340 - val_accuracy: 0.9427 - val_loss: 0.2294
# Epoch 5/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9497 - loss: 0.2008 - val_accuracy: 0.9427 - val_loss: 0.2285
# Epoch 6/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9478 - loss: 0.1928 - val_accuracy: 0.9427 - val_loss: 0.2269
# Epoch 7/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9450 - loss: 0.2025 - val_accuracy: 0.9427 - val_loss: 0.2266
# Epoch 8/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9442 - loss: 0.2056 - val_accuracy: 0.9427 - val_loss: 0.2290
# Epoch 9/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9407 - loss: 0.2071 - val_accuracy: 0.9427 - val_loss: 0.2321
# Epoch 10/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9574 - loss: 0.1684 - val_accuracy: 0.9427 - val_loss: 0.2286
# Epoch 11/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9426 - loss: 0.1904 - val_accuracy: 0.9427 - val_loss: 0.2306
# Epoch 12/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9523 - loss: 0.1688 - val_accuracy: 0.9427 - val_loss: 0.2336
# Epoch 13/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9491 - loss: 0.1795 - val_accuracy: 0.9427 - val_loss: 0.2289
# Epoch 14/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9547 - loss: 0.1599 - val_accuracy: 0.9427 - val_loss: 0.2272
# Epoch 15/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9509 - loss: 0.1726 - val_accuracy: 0.9427 - val_loss: 0.2328
# Epoch 16/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9538 - loss: 0.1583 - val_accuracy: 0.9427 - val_loss: 0.2312
# Epoch 17/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9505 - loss: 0.1555 - val_accuracy: 0.9427 - val_loss: 0.2356
# Epoch 18/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9472 - loss: 0.1686 - val_accuracy: 0.9427 - val_loss: 0.2393
# Epoch 19/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9600 - loss: 0.1304 - val_accuracy: 0.9427 - val_loss: 0.2387
# Epoch 20/50
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.